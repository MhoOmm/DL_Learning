# %%
import torch

# %% [markdown]
# # Simple Example

# %% [markdown]
# Y = x^2

# %%
x = torch.tensor(3.0,requires_grad=True)

# %%
y = x**2 # Pytorch monitoring now learns the function between y and x

# %%
y.backward() # caluculates the backward gradient

# %%
x.grad # returns the calculated value
# Out:
# tensor(12.)

# %% [markdown]
# y = x^2
# z = sin(y)

# %%
x = torch.tensor(3.0,requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
z = torch.sin(y)
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-5.4668)

# %% [markdown]
# Neural Network

# %%
# Manually calculating
x = torch.tensor(6.7)
y = torch.tensor(0.0)

w = torch.tensor(1.0)
b = torch.tensor(0.0)

# %%
def binary_cross_entropy(prediction,target):
  epsilon = 1e-8 # to prevent log(0)
  prediction = torch.clamp(prediction,epsilon,1-epsilon)
  return -(target*torch.log(prediction)+(1-target)*torch.log(1-prediction))

# %%
# forward
z = w*x + b
y_pred = torch.sigmoid(z)
loss = binary_cross_entropy(y_pred,y)
loss
# Out:
# tensor(6.7012)

# %%
# Derivatives:
# 1. dL/d(y_pred): Loss with respect to the prediction (y_pred)
dloss_dy_pred = (y_pred - y)/(y_pred*(1-y_pred))

# 2. dy_pred/dz: Prediction (y_pred) with respect to z (sigmoid derivative)
dy_pred_dz = y_pred * (1 - y_pred)

# 3. dz/dw and dz/db: z with respect to w and b
dz_dw = x  # dz/dw = x
dz_db = 1  # dz/db = 1 (bias contributes directly to z)

dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual Gradient of loss w.r.t weight (dw): {dL_dw}")
print(f"Manual Gradient of loss w.r.t bias (db): {dL_db}")
# Out:
# Manual Gradient of loss w.r.t weight (dw): 6.691762447357178
# Manual Gradient of loss w.r.t bias (db): 0.998770534992218

# %% [markdown]
# Mentos Zindagi

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

w = torch.tensor(1.0,requires_grad=True)
b = torch.tensor(0.0,requires_grad=True)

# %%
z = w*x+b

# %%
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy(y_pred,y)
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
w.grad
# Out:
# tensor(6.6918)

# %%
b.grad
# Out:
# tensor(0.9988)

# %% [markdown]
# Vector Inputs

# %%
x = torch.tensor([1.0,2.0,3.0],requires_grad=True)

# %%
y =(x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %% [markdown]
# #Clearing Grad

# %%
x = torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
y = x**2

# %%
y.backward()

# %%
x.grad # answer came 8 instead of 4 coz the gradient didnt clear up and we have to clear it up - gradient accumulate
# Out:
# tensor(8.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %%
y = x**2

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %% [markdown]
# #Disabling Gradient Tracking

# %% [markdown]
# After neural network training we need the wwights freezed for prediction and we dont need to diffrentiate them again, so we can disable the gradient tracking

# %%
x = torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %% [markdown]
# Now i want to disable tracking

# %%
# option 1 - requires_grad_(False)
x.requires_grad_(False)
# Out:
# tensor(2.)

# %%
y = x**2

# %%
y
# Out:
# tensor(4.)

# %%
# Option 2 - detach - we make a new tensor

# %%
z= x.detach() # ismein gradient traking nhi hoga but has exact values as x

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %% [markdown]
# grad_fn=PowBackward0 idhar it is tracking but in the below example it is not

# %%
y1 = z**2
y1
# Out:
# tensor(4.)

# %%
# options 3 with option

# %%
x = torch.tensor(2.0,requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
with torch.no_grad():
  y = x**2

y
# Out:
# tensor(4.)

# %% [markdown]
# but isko nhi kiya to it will track

# %%
y=x**2

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)
